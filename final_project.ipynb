# %%
import numpy as np
from bokeh.models import HoverTool
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import pandas as pd

# %%
cities = pd.read_csv('Interactive Data Final Project.csv')
cities
# Out:
#    Popular U.S. Cities (50) Entry-Level Marketing Starting Salary  \
# 0           New Orleans, LA                              $41,997
# 1                 Tampa, FL                              $40,829
# 2             Arlington, TX                              $41,730
# 3                 Tulsa, OK                              $40,855
# 4           Minneapolis, MN                              $45,702
# 5               Oakland, CA                              $52,334
# 6                 Miami, FL                              $41,632
# 7            Long Beach, CA                              $47,830
# 8        Virginia Beach, VA                              $41,009
# 9               Raleigh, NC                              $41,811
# 10     Colorado Springs, CO                              $42,695
# 11                Omaha, NE                              $40,556
# 12              Atlanta, GA                              $42,133
# ...

# %%
cities_new = cities.groupby("Popular U.S. Cities (50)")
cities_new

# %%
population = cities.groupby("Cities' Population (2021)")
population
